# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./Dataset/Manisha/IMG_20181201_164547.jpg')
img.shape
# Out:
# (4618, 3464, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (4618, 3464)

# %%
gray
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 951,  753, 1637, 1637]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (951, 753, 1637, 1637)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray')
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1637, 1637, 3)

# %% [markdown]
# # def get_cropped_image_if_2_eyes(image_path):
#     img = cv2.imread(image_path)
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#     for (x,y,w,h) in faces:
#         roi_gray = gray[y:y+h, x:x+w]
#         roi_color = img[y:y+h, x:x+w]
#         eyes = eye_cascade.detectMultiScale(roi_gray)
#         if len(eyes) >= 2:
#             return roi_color

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                            return roi_color

# %%
path_to_data = "./Dataset/"
path_to_cr_data = "./cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./Dataset/Priyanka',
#  './Dataset/Prashant',
#  './Dataset/Meetesh',
#  './Dataset/Manisha']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count+= 1
# Out:
# Priyanka
# Generating cropped images in folder:  ./cropped/Priyanka
# Prashant
# Generating cropped images in folder:  ./cropped/Prashant
# Meetesh
# Generating cropped images in folder:  ./cropped/Meetesh
# Manisha
# Generating cropped images in folder:  ./cropped/Manisha

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Priyanka': ['./cropped/Priyanka/Priyanka101.png',
#   './cropped/Priyanka/Priyanka115.png',
#   './cropped/Priyanka/Priyanka12.png',
#   './cropped/Priyanka/Priyanka13.png',
#   './cropped/Priyanka/Priyanka114.png',
#   './cropped/Priyanka/Priyanka100.png',
#   './cropped/Priyanka/Priyanka116.png',
#   './cropped/Priyanka/Priyanka102.png',
#   './cropped/Priyanka/Priyanka39.png',
#   './cropped/Priyanka/Priyanka11.png',
#   './cropped/Priyanka/Priyanka10.png',
#   './cropped/Priyanka/Priyanka38.png',
#   './cropped/Priyanka/Priyanka103.png',
#   './cropped/Priyanka/Priyanka117.png',
#   './cropped/Priyanka/Priyanka113.png',
#   './cropped/Priyanka/Priyanka107.png',
#   './cropped/Priyanka/Priyanka14.png',
#   './cropped/Priyanka/.DS_Store',
#   './cropped/Priyanka/Priyanka28.png',
#   './cropped/Priyanka/Priyanka9.png',
#   './cropped/Priyanka/Priyanka8.png',
#   './cropped/Priyanka/Priyanka29.png',
#   './cropped/Priyanka/Priyanka15.png',
#   './cropped/Priyanka/Priyanka106.png',
#   './cropped/Priyanka/Priyanka112.png',
#   './cropped/Priyanka/Priyanka104.png',
#   './cropped/Priyanka/Priyanka110.png',
#   './cropped/Priyanka/Priyanka17.png',
#   './cropped/Priyanka/Priyanka16.png',
#   './cropped/Priyanka/Priyanka111.png',
#   './cropped/Priyanka/Priyanka105.png',
#   './cropped/Priyanka/Priyanka59.png',
#   './cropped/Priyanka/Priyanka65.png',
#   './cropped/Priyanka/Priyanka71.png',
#   './cropped/Priyanka/Priyanka70.png',
#   './cropped/Priyanka/Priyanka64.png',
#   './cropped/Prashant/Prashant24.png',
#   './cropped/Prashant/Prashant148.png',
#   './cropped/Prashant/Prashant18.png',
#   './cropped/Prashant/Prashant161.png',
#   './cropped/Prashant/Prashant149.png',
#   './cropped/Prashant/Prashant31.png',
#   './cropped/Prashant/Prashant27.png',
#   './cropped/Prashant/Prashant162.png',
#   './cropped/Prashant/Prashant26.png',
#   './cropped/Prashant/Prashant22.png',
#   './cropped/Prashant/Prashant36.png',
#   './cropped/Prashant/Prashant23.png',
#   './cropped/Prashant/Prashant167.png',
#   './cropped/Prashant/Prashant165.png',
#   './cropped/Prashant/Prashant171.png',
#   './cropped/Prashant/Prashant35.png',
#   './cropped/Prashant/Prashant159.png',
#   './cropped/Prashant/Prashant21.png',
#   './cropped/Prashant/Prashant158.png',
#   './cropped/Prashant/Prashant170.png',
#   './cropped/Prashant/Prashant53.png',
#   './cropped/Prashant/Prashant47.png',
#   './cropped/Prashant/Prashant103.png',
#   './cropped/Prashant/Prashant90.png',
#   './cropped/Prashant/Prashant2.png',
#   './cropped/Prashant/Prashant3.png',
#   './cropped/Prashant/Prashant85.png',
#   './cropped/Prashant/Prashant91.png',
#   './cropped/Prashant/Prashant116.png',
#   './cropped/Prashant/Prashant52.png',
#   './cropped/Prashant/Prashant44.png',
#   './cropped/Prashant/Prashant128.png',
#   './cropped/Prashant/Prashant78.png',
#   './cropped/Prashant/Prashant1.png',
#   './cropped/Prashant/Prashant92.png',
#   './cropped/Prashant/Prashant86.png',
#   './cropped/Prashant/Prashant79.png',
#   './cropped/Prashant/Prashant115.png',
#   './cropped/Prashant/Prashant129.png',
#   './cropped/Prashant/Prashant111.png',
#   './cropped/Prashant/Prashant105.png',
#   './cropped/Prashant/Prashant69.png',
#   './cropped/Prashant/Prashant55.png',
#   './cropped/Prashant/Prashant96.png',
#   './cropped/Prashant/Prashant54.png',
#   './cropped/Prashant/Prashant106.png',
#   './cropped/Prashant/Prashant42.png',
#   './cropped/Prashant/Prashant95.png',
#   './cropped/Prashant/Prashant7.png',
#   './cropped/Prashant/Prashant6.png',
#   './cropped/Prashant/Prashant80.png',
#   './cropped/Prashant/Prashant94.png',
#   './cropped/Prashant/Prashant107.png'],
#  'Meetesh': ['./cropped/Meetesh/Meetesh52.png',
#   './cropped/Meetesh/Meetesh90.png',
#   './cropped/Meetesh/Meetesh87.png',
#   './cropped/Meetesh/Meetesh44.png',
#   './cropped/Meetesh/.DS_Store',
#   './cropped/Meetesh/Meetesh97.png',
#   './cropped/Meetesh/Meetesh5.png',
#   './cropped/Meetesh/Meetesh31.png',
#   './cropped/Meetesh/Meetesh17.png',
#   './cropped/Meetesh/Meetesh9.png',
#   './cropped/Meetesh/Meetesh67.png',
#   './cropped/Meetesh/Meetesh8.png',
#   './cropped/Meetesh/Meetesh58.png',
#   './cropped/Meetesh/Meetesh70.png',
#   './cropped/Meetesh/Meetesh64.png',
#   './cropped/Meetesh/Meetesh71.png'],
#  'Manisha': ['./cropped/Manisha/Manisha207.png',
#   './cropped/Manisha/Manisha165.png',
#   './cropped/Manisha/Manisha171.png',
#   './cropped/Manisha/Manisha159.png',
#   './cropped/Manisha/Manisha401.png',
#   './cropped/Manisha/Manisha429.png',
#   './cropped/Manisha/Manisha31.png',
#   './cropped/Manisha/Manisha398.png',
#   './cropped/Manisha/Manisha24.png',
#   './cropped/Manisha/Manisha30.png',
#   './cropped/Manisha/Manisha428.png',
#   './cropped/Manisha/Manisha414.png',
#   './cropped/Manisha/Manisha158.png',
#   './cropped/Manisha/Manisha170.png',
#   './cropped/Manisha/Manisha3.png',
#   './cropped/Manisha/Manisha210.png',
#   './cropped/Manisha/Manisha166.png',
#   './cropped/Manisha/Manisha416.png',
#   './cropped/Manisha/Manisha402.png',
#   './cropped/Manisha/Manisha358.png',
#   './cropped/Manisha/Manisha26.png',
#   './cropped/Manisha/Manisha27.png',
#   './cropped/Manisha/Manisha359.png',
#   './cropped/Manisha/Manisha403.png',
#   './cropped/Manisha/Manisha365.png',
#   './cropped/Manisha/Manisha371.png',
#   './cropped/Manisha/Manisha417.png',
#   './cropped/Manisha/Manisha198.png',
#   './cropped/Manisha/Manisha173.png',
#   './cropped/Manisha/Manisha205.png',
#   './cropped/Manisha/Manisha201.png',
#   './cropped/Manisha/Manisha215.png',
#   './cropped/Manisha/Manisha177.png',
#   './cropped/Manisha/Manisha4.png',
#   './cropped/Manisha/.DS_Store',
#   './cropped/Manisha/Manisha413.png',
#   './cropped/Manisha/Manisha375.png',
#   './cropped/Manisha/Manisha23.png',
#   './cropped/Manisha/Manisha22.png',
#   './cropped/Manisha/Manisha406.png',
#   './cropped/Manisha/Manisha348.png',
#   './cropped/Manisha/Manisha189.png',
#   './cropped/Manisha/Manisha162.png',
#   './cropped/Manisha/Manisha176.png',
#   './cropped/Manisha/Manisha200.png',
#   './cropped/Manisha/Manisha228.png',
#   './cropped/Manisha/Manisha216.png',
#   './cropped/Manisha/Manisha202.png',
#   './cropped/Manisha/Manisha148.png',
#   './cropped/Manisha/Manisha160.png',
#   './cropped/Manisha/Manisha7.png',
#   './cropped/Manisha/Manisha174.png',
#   './cropped/Manisha/Manisha438.png',
#   './cropped/Manisha/Manisha404.png',
#   './cropped/Manisha/Manisha410.png',
#   './cropped/Manisha/Manisha21.png',
#   './cropped/Manisha/Manisha388.png',
#   './cropped/Manisha/Manisha411.png',
#   './cropped/Manisha/Manisha439.png',
#   './cropped/Manisha/Manisha161.png',
#   './cropped/Manisha/Manisha149.png',
#   './cropped/Manisha/Manisha203.png',
#   './cropped/Manisha/Manisha217.png',
#   './cropped/Manisha/Manisha270.png',
#   './cropped/Manisha/Manisha264.png',
#   './cropped/Manisha/Manisha258.png',
#   './cropped/Manisha/Manisha106.png',
#   './cropped/Manisha/Manisha91.png',
#   './cropped/Manisha/Manisha310.png',
#   './cropped/Manisha/Manisha85.png',
#   './cropped/Manisha/Manisha52.png',
#   './cropped/Manisha/Manisha53.png',
#   './cropped/Manisha/Manisha339.png',
#   './cropped/Manisha/Manisha311.png',
#   './cropped/Manisha/Manisha90.png',
#   './cropped/Manisha/Manisha113.png',
#   './cropped/Manisha/Manisha259.png',
#   './cropped/Manisha/Manisha265.png',
#   './cropped/Manisha/Manisha273.png',
#   './cropped/Manisha/Manisha139.png',
#   './cropped/Manisha/Manisha86.png',
#   './cropped/Manisha/Manisha92.png',
#   './cropped/Manisha/Manisha461.png',
#   './cropped/Manisha/Manisha45.png',
#   './cropped/Manisha/Manisha79.png',
#   './cropped/Manisha/Manisha448.png',
#   './cropped/Manisha/Manisha93.png',
#   './cropped/Manisha/Manisha312.png',
#   './cropped/Manisha/Manisha104.png',
#   './cropped/Manisha/Manisha272.png',
#   './cropped/Manisha/Manisha266.png',
#   './cropped/Manisha/Manisha276.png',
#   './cropped/Manisha/Manisha289.png',
#   './cropped/Manisha/Manisha128.png',
#   './cropped/Manisha/Manisha100.png',
#   './cropped/Manisha/Manisha458.png',
#   './cropped/Manisha/Manisha83.png',
#   './cropped/Manisha/Manisha97.png',
#   './cropped/Manisha/Manisha302.png',
#   './cropped/Manisha/Manisha40.png',
#   './cropped/Manisha/Manisha54.png',
#   './cropped/Manisha/Manisha55.png',
#   './cropped/Manisha/Manisha41.png',
#   './cropped/Manisha/Manisha69.png',
#   './cropped/Manisha/Manisha303.png',
#   './cropped/Manisha/Manisha317.png',
#   './cropped/Manisha/Manisha459.png',
#   './cropped/Manisha/Manisha101.png',
#   './cropped/Manisha/Manisha115.png',
#   './cropped/Manisha/Manisha129.png',
#   './cropped/Manisha/Manisha288.png',
#   './cropped/Manisha/Manisha277.png',
#   './cropped/Manisha/Manisha263.png',
#   './cropped/Manisha/Manisha249.png',
#   './cropped/Manisha/Manisha261.png',
#   './cropped/Manisha/Manisha103.png',
#   './cropped/Manisha/Manisha329.png',
#   './cropped/Manisha/Manisha301.png',
#   './cropped/Manisha/Manisha57.png',
#   './cropped/Manisha/Manisha43.png',
#   './cropped/Manisha/Manisha314.png',
#   './cropped/Manisha/Manisha95.png',
#   './cropped/Manisha/Manisha328.png',
#   './cropped/Manisha/Manisha116.png',
#   './cropped/Manisha/Manisha102.png',
#   './cropped/Manisha/Manisha260.png',
#   './cropped/Manisha/Manisha251.png',
#   './cropped/Manisha/Manisha245.png',
#   './cropped/Manisha/Manisha279.png',
#   './cropped/Manisha/Manisha127.png',
#   './cropped/Manisha/Manisha325.png',
#   './cropped/Manisha/Manisha457.png',
#   './cropped/Manisha/Manisha319.png',
#   './cropped/Manisha/Manisha73.png',
#   './cropped/Manisha/Manisha66.png',
#   './cropped/Manisha/Manisha99.png',
#   './cropped/Manisha/Manisha318.png',
#   './cropped/Manisha/Manisha330.png',
#   './cropped/Manisha/Manisha456.png',
#   './cropped/Manisha/Manisha324.png',
#   './cropped/Manisha/Manisha287.png',
#   './cropped/Manisha/Manisha293.png',
#   './cropped/Manisha/Manisha278.png',
#   './cropped/Manisha/Manisha246.png',
#   './cropped/Manisha/Manisha130.png',
#   './cropped/Manisha/Manisha124.png',
#   './cropped/Manisha/Manisha118.png',
#   './cropped/Manisha/Manisha326.png',
#   './cropped/Manisha/Manisha440.png',
#   './cropped/Manisha/Manisha64.png',
#   './cropped/Manisha/Manisha70.png',
#   './cropped/Manisha/Manisha58.png',
#   './cropped/Manisha/Manisha59.png',
#   './cropped/Manisha/Manisha71.png',
#   './cropped/Manisha/Manisha65.png',
#   './cropped/Manisha/Manisha455.png',
#   './cropped/Manisha/Manisha333.png',
#   './cropped/Manisha/Manisha290.png',
#   './cropped/Manisha/Manisha284.png',
#   './cropped/Manisha/Manisha253.png',
#   './cropped/Manisha/Manisha247.png',
#   './cropped/Manisha/Manisha257.png',
#   './cropped/Manisha/Manisha294.png',
#   './cropped/Manisha/Manisha109.png',
#   './cropped/Manisha/Manisha121.png',
#   './cropped/Manisha/Manisha451.png',
#   './cropped/Manisha/Manisha61.png',
#   './cropped/Manisha/Manisha444.png',
#   './cropped/Manisha/Manisha120.png',
#   './cropped/Manisha/Manisha134.png',
#   './cropped/Manisha/Manisha108.png',
#   './cropped/Manisha/Manisha295.png',
#   './cropped/Manisha/Manisha281.png',
#   './cropped/Manisha/Manisha242.png',
#   './cropped/Manisha/Manisha254.png',
#   './cropped/Manisha/Manisha240.png',
#   './cropped/Manisha/Manisha297.png',
#   './cropped/Manisha/Manisha283.png',
#   './cropped/Manisha/Manisha122.png',
#   './cropped/Manisha/Manisha320.png',
#   './cropped/Manisha/Manisha446.png',
#   './cropped/Manisha/Manisha452.png',
#   './cropped/Manisha/Manisha334.png',
#   './cropped/Manisha/Manisha88.png',
#   './cropped/Manisha/Manisha137.png',
#   './cropped/Manisha/Manisha296.png',
#   './cropped/Manisha/Manisha269.png',
#   './cropped/Manisha/Manisha226.png',
#   './cropped/Manisha/Manisha150.png',
#   './cropped/Manisha/Manisha178.png',
#   './cropped/Manisha/Manisha193.png',
#   './cropped/Manisha/Manisha346.png',
#   './cropped/Manisha/Manisha352.png',
#   './cropped/Manisha/Manisha408.png',
#   './cropped/Manisha/Manisha385.png',
#   './cropped/Manisha/Manisha10.png',
#   './cropped/Manisha/Manisha391.png',
#   './cropped/Manisha/Manisha38.png',
#   './cropped/Manisha/Manisha390.png',
#   './cropped/Manisha/Manisha11.png',
#   './cropped/Manisha/Manisha409.png',
#   './cropped/Manisha/Manisha435.png',
#   './cropped/Manisha/Manisha353.png',
#   './cropped/Manisha/Manisha192.png',
#   './cropped/Manisha/Manisha179.png',
#   './cropped/Manisha/Manisha145.png',
#   './cropped/Manisha/Manisha233.png',
#   './cropped/Manisha/Manisha153.png',
#   './cropped/Manisha/Manisha147.png',
#   './cropped/Manisha/Manisha8.png',
#   './cropped/Manisha/Manisha190.png',
#   './cropped/Manisha/Manisha351.png',
#   './cropped/Manisha/Manisha437.png',
#   './cropped/Manisha/Manisha345.png',
#   './cropped/Manisha/Manisha379.png',
#   './cropped/Manisha/Manisha386.png',
#   './cropped/Manisha/Manisha12.png',
#   './cropped/Manisha/Manisha378.png',
#   './cropped/Manisha/Manisha422.png',
#   './cropped/Manisha/Manisha344.png',
#   './cropped/Manisha/Manisha436.png',
#   './cropped/Manisha/Manisha146.png',
#   './cropped/Manisha/Manisha152.png',
#   './cropped/Manisha/Manisha218.png',
#   './cropped/Manisha/Manisha224.png',
#   './cropped/Manisha/Manisha220.png',
#   './cropped/Manisha/Manisha142.png',
#   './cropped/Manisha/Manisha195.png',
#   './cropped/Manisha/Manisha368.png',
#   './cropped/Manisha/Manisha432.png',
#   './cropped/Manisha/Manisha354.png',
#   './cropped/Manisha/Manisha340.png',
#   './cropped/Manisha/Manisha426.png',
#   './cropped/Manisha/Manisha382.png',
#   './cropped/Manisha/Manisha396.png',
#   './cropped/Manisha/Manisha341.png',
#   './cropped/Manisha/Manisha427.png',
#   './cropped/Manisha/Manisha433.png',
#   './cropped/Manisha/Manisha180.png',
#   './cropped/Manisha/Manisha221.png',
#   './cropped/Manisha/Manisha209.png',
#   './cropped/Manisha/Manisha169.png',
#   './cropped/Manisha/Manisha141.png',
#   './cropped/Manisha/Manisha155.png',
#   './cropped/Manisha/Manisha182.png',
#   './cropped/Manisha/Manisha196.png',
#   './cropped/Manisha/Manisha343.png',
#   './cropped/Manisha/Manisha29.png',
#   './cropped/Manisha/Manisha15.png',
#   './cropped/Manisha/Manisha380.png',
#   './cropped/Manisha/Manisha14.png',
#   './cropped/Manisha/Manisha28.png',
#   './cropped/Manisha/Manisha424.png',
#   './cropped/Manisha/Manisha418.png',
#   './cropped/Manisha/Manisha197.png',
#   './cropped/Manisha/Manisha183.png',
#   './cropped/Manisha/Manisha154.png',
#   './cropped/Manisha/Manisha168.png',
#   './cropped/Manisha/Manisha222.png',
#   './cropped/Manisha/Manisha236.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Priyanka': 0, 'Prashant': 1, 'Meetesh': 2, 'Manisha': 3}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is not None:
            scalled_raw_img = cv2.resize(img, (32, 32))
            img_har = w2d(img,'db1',5)
            scalled_img_har = cv2.resize(img_har, (32, 32))
            combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
            X.append(combined_img)
            y.append(class_dict[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (495, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8548387096774194

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        28
#            1       0.92      0.85      0.88        26
#            2       1.00      0.25      0.40         4
#            3       0.87      0.94      0.91        66
#
#     accuracy                           0.85       124
#    macro avg       0.88      0.70      0.73       124
# weighted avg       0.86      0.85      0.85       124

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.854306
# 1        random_forest    0.735964
# 2  logistic_regression    0.827279
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8790322580645161

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7741935483870968

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8548387096774194

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[24,  0,  0,  4],
#        [ 0, 24,  1,  1],
#        [ 2,  1,  0,  1],
#        [ 5,  0,  0, 61]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Priyanka': 0, 'Prashant': 1, 'Meetesh': 2, 'Manisha': 3}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /Users/prashant/opt/anaconda3/lib/python3.9/site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement util (from versions: none)
# ERROR: No matching distribution found for util
